# %% [markdown]
# # Report tugas : **Deploy Aplikasi**

# %% [markdown]
# NAMA : Mohammad Iqbal Surya Ramadhan
#
# NIM  : 210411100002
#
# MATA KULIAH : Pencarian dan Penambangan Web - A

# %% [markdown]
# **Aplikasi Klasifikasi Berita :**
# Memaasukkan teks berita untuk mengetahui kategori topik utama (Otomitif atau Keuagan).
#
# https://huggingface.co/spaces/Iqbalsr/Klasifikasiberita

# %% [markdown]
# **Proses Berita dan Analisis Similarity :**
# Aplikasi ini memproses berita, menghitung similarity antar kalimat, dan menampilkan centrality measures.
#
# https://huggingface.co/spaces/Iqbalsr/RangkumanGraph

# %% [markdown]
# **Aplikasi Klasifikasi Berita (SVD) :**
# Aplikasi ini mengklasifikasikan berita ke dalam kategori Keuagan dan Otomotif menggunakan Logistic Regression dan Reduksi Dimensi dengan Singular Value Decomposition (SVD).
#
#
# https://huggingface.co/spaces/Iqbalsr/Reduksidimensiberita

# %% [markdown]
# **Aplikasi Klasifikasi Berita (SVD & FCM) :**
# Aplikasi ini mengklasifikasikan berita ke dalam kategori Otomotif dan Keuangan menggunakan pipeline SVD dan FCM.
#
# https://huggingface.co/spaces/Iqbalsr/Klasifikasi_fuzzycmeans
