# %% [markdown]
# # Membuat Sebuah Webstatis

# %% [markdown]
# NAMA : Mohammad Iqbal Surya Ramadhan
#
# NIM  : 210411100002
#
# MATA KULIAH : Pencarian dan Penambangan Web - A

# %% [markdown]
# Untuk membuat sebuah webstatis kita memerlukan pembuatan repository pada github dan folder pada drive yang akan digunakan.
